# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models

# %%
from ultralytics import YOLO

# %%
model_yolo_trained = YOLO("best.pt")

# %%
test_dir = 'images/test/images'
test_images = [os.path.join(test_dir, f) for f in os.listdir(test_dir) if f.endswith('.jpg')]

# %%
import matplotlib.pyplot as plt
import cv2

# Run prediction and save the result
results = model_yolo_trained(source=test_images[168], save=True, save_txt=False, show=False)

# The result image is saved in 'runs/detect/predict' by default
pred_img_path = 'runs/detect/predict/' + os.path.basename(test_images[168])
pred_img_path = 'C:/Users/dulea/Downloads/humerus-fracture-midshaft.jpg'
# Display the image in the notebook
img = cv2.imread(pred_img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 d:\BoneSight_AI\BoneSight-AI\images\test\images\image2_953_png.rf.97a41890b4badde45bfc390f9f5c9d12.jpg: 416x352 1 forearm fracture, 19.8ms
# Speed: 2.6ms preprocess, 19.8ms inference, 4.2ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to runs\detect\predict13
