# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models

# %%
from ultralytics import YOLO

# %%
model_yolo_trained = YOLO("best_fracture_detector.pt")

# %%
test_dir = 'images/test/images'
test_images = [os.path.join(test_dir, f) for f in os.listdir(test_dir) if f.endswith('.jpg')]

# %%
import matplotlib.pyplot as plt
import cv2

pred_img_path = 'C:/Users/dulea/Downloads/leg_fracture.jpeg'
results = model_yolo_trained(source=pred_img_path, conf=0.01, save=True, save_txt=False, show=False)
# Out:
# image 1/1 C:\Users\dulea\Downloads\leg_fracture.jpeg: 512x512 3 fractures, 7.1ms
# Speed: 0.9ms preprocess, 7.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to D:\Bonesight_AI\BoneSight-AI\runs\detect\predict21
